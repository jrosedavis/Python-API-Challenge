# %% [markdown]
# WeatherPy
#
# Note:
# Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
#Confirm API key was accepted

#weather_api_key

# %% [markdown]
# Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 628

# %% [markdown]
# Perform API Calls
#
# Perform a weather check on each city using a series of successive API calls.
# Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#Working with a loop
url = "http://api.openweathermap.org/data/2.5/weather?"

#Set up lists to hold response info
nameofcity = []
lat1 = []
lng1 = []
maxT = []
hum = []
wind_spd = []
country = []
date = []
clouds = []
counter = 0
sets = 1

# Loop through the list of cities set by previous loop and perform a request for data on each []
print("-------Beginning of Data Retrieval--------")

for city in cities:
    city=city
    
    query_url = url + "&q=" + city + "&appid=" + weather_api_key + "&units=Imperial"
    response = requests.get(query_url).json()
    
    try:
        print(f"Processing Record {counter} of Set {sets} | {city}")
        nameofcity.append(response['name'])
        lat1.append(response['coord']['lat'])
        lng1.append(response['coord']['lon'])
        maxT.append(response['main']['temp_max'])
        hum.append(response['main']['humidity'])
        wind_spd.append(response['wind']['speed'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        clouds.append(response['clouds']['all'])

    except: 
        print('City not found. Skipping...')
        lat1.append(np.nan)
        lng1.append(np.nan)
        maxT.append(np.nan)
        hum.append(np.nan)
        wind_spd.append(np.nan)
        country.append(np.nan)
        date.append(np.nan)
        clouds.append(np.nan)
        
    counter = counter + 1
    if counter == 50:
        counter = 0
        sets = sets + 1

print("-----------------------")      
print("Data Retrieval Complete")
print("-----------------------")
# Out:
# -------Beginning of Data Retrieval--------
# Processing Record 0 of Set 1 | port elizabeth
# Processing Record 1 of Set 1 | vanimo
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | jamestown
# Processing Record 4 of Set 1 | hobart
# Processing Record 5 of Set 1 | lebu
# Processing Record 6 of Set 1 | apango
# Processing Record 7 of Set 1 | carutapera
# Processing Record 8 of Set 1 | hamilton
# Processing Record 9 of Set 1 | hilo
# Processing Record 10 of Set 1 | shieli
# Processing Record 11 of Set 1 | mataura
# Processing Record 12 of Set 1 | dergachi
# Processing Record 13 of Set 1 | butaritari
# Processing Record 14 of Set 1 | morant bay
# Processing Record 15 of Set 1 | manggar
# Processing Record 16 of Set 1 | patnanungan
# Processing Record 17 of Set 1 | saldanha
# Processing Record 18 of Set 1 | dudinka
# Processing Record 19 of Set 1 | busselton
# Processing Record 20 of Set 1 | sinop
# Processing Record 21 of Set 1 | santander
# Processing Record 22 of Set 1 | naze
# Processing Record 23 of Set 1 | cape town
# Processing Record 24 of Set 1 | ngunguru
# Processing Record 25 of Set 1 | arlit
# Processing Record 26 of Set 1 | visnes
# Processing Record 27 of Set 1 | sorvag
# City not found. Skipping...
# Processing Record 28 of Set 1 | sarangani
# Processing Record 29 of Set 1 | atuona
# Processing Record 30 of Set 1 | mackenzie
# Processing Record 31 of Set 1 | bethel
# Processing Record 32 of Set 1 | coihaique
# Processing Record 33 of Set 1 | punta arenas
# Processing Record 34 of Set 1 | qaanaaq
# Processing Record 35 of Set 1 | roma
# Processing Record 36 of Set 1 | avarua
# Processing Record 37 of Set 1 | awbari
# Processing Record 38 of Set 1 | chuy
# Processing Record 39 of Set 1 | san luis
# Processing Record 40 of Set 1 | sao filipe
# Processing Record 41 of Set 1 | salinopolis
# Processing Record 42 of Set 1 | upernavik
# Processing Record 43 of Set 1 | hithadhoo
# Processing Record 44 of Set 1 | cheuskiny
# City not found. Skipping...
# Processing Record 45 of Set 1 | albany
# Processing Record 46 of Set 1 | puerto ayora
# Processing Record 47 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 48 of Set 1 | torbay
# Processing Record 49 of Set 1 | tiarei
# Processing Record 0 of Set 2 | saskylakh
# Processing Record 1 of Set 2 | jumla
# Processing Record 2 of Set 2 | chokurdakh
# Processing Record 3 of Set 2 | bluff
# Processing Record 4 of Set 2 | kahului
# Processing Record 5 of Set 2 | vila velha
# Processing Record 6 of Set 2 | huarmey
# Processing Record 7 of Set 2 | fortuna
# Processing Record 8 of Set 2 | dolores
# Processing Record 9 of Set 2 | ostersund
# Processing Record 10 of Set 2 | jian
# Processing Record 11 of Set 2 | champerico
# Processing Record 12 of Set 2 | mahebourg
# Processing Record 13 of Set 2 | sorland
# Processing Record 14 of Set 2 | rikitea
# Processing Record 15 of Set 2 | puerto leguizamo
# Processing Record 16 of Set 2 | canton
# Processing Record 17 of Set 2 | atambua
# Processing Record 18 of Set 2 | jalu
# Processing Record 19 of Set 2 | lakselv
# Processing Record 20 of Set 2 | hermanus
# Processing Record 21 of Set 2 | eureka
# Processing Record 22 of Set 2 | kapaa
# Processing Record 23 of Set 2 | zhigansk
# Processing Record 24 of Set 2 | viedma
# Processing Record 25 of Set 2 | henties bay
# Processing Record 26 of Set 2 | fairbanks
# Processing Record 27 of Set 2 | sistranda
# Processing Record 28 of Set 2 | cherskiy
# Processing Record 29 of Set 2 | georgetown
# Processing Record 30 of Set 2 | komsomolskiy
# Processing Record 31 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 32 of Set 2 | olafsvik
# Processing Record 33 of Set 2 | ponta do sol
# Processing Record 34 of Set 2 | ilo
# Processing Record 35 of Set 2 | cayenne
# Processing Record 36 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 37 of Set 2 | barinas
# Processing Record 38 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 39 of Set 2 | hasaki
# Processing Record 40 of Set 2 | qaqortoq
# Processing Record 41 of Set 2 | benavente
# Processing Record 42 of Set 2 | mont-de-marsan
# Processing Record 43 of Set 2 | cirebon
# Processing Record 44 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 45 of Set 2 | bredasdorp
# Processing Record 46 of Set 2 | port alfred
# Processing Record 47 of Set 2 | touros
# Processing Record 48 of Set 2 | dingle
# Processing Record 49 of Set 2 | ahipara
# Processing Record 0 of Set 3 | lorengau
# Processing Record 1 of Set 3 | saint-philippe
# Processing Record 2 of Set 3 | cidreira
# Processing Record 3 of Set 3 | manokwari
# Processing Record 4 of Set 3 | sangin
# Processing Record 5 of Set 3 | leningradskiy
# Processing Record 6 of Set 3 | monywa
# Processing Record 7 of Set 3 | homer
# Processing Record 8 of Set 3 | urucara
# Processing Record 9 of Set 3 | barrow
# Processing Record 10 of Set 3 | gbarnga
# Processing Record 11 of Set 3 | nelson bay
# Processing Record 12 of Set 3 | port lincoln
# Processing Record 13 of Set 3 | richards bay
# Processing Record 14 of Set 3 | yellowknife
# Processing Record 15 of Set 3 | varhaug
# Processing Record 16 of Set 3 | pochutla
# Processing Record 17 of Set 3 | port hardy
# Processing Record 18 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record
# Processing Record 34 of Set 4 | petropavl
# Processing Record 35 of Set 4 | dondo
# Processing Record 36 of Set 4 | ribeira grande
# Processing Record 37 of Set 4 | sumenep
# Processing Record 38 of Set 4 | muros
# Processing Record 39 of Set 4 | dabakala
# Processing Record 40 of Set 4 | pyaozerskiy
# Processing Record 41 of Set 4 | rawson
# Processing Record 42 of Set 4 | popondetta
# Processing Record 43 of Set 4 | den helder
# Processing Record 44 of Set 4 | te anau
# Processing Record 45 of Set 4 | ewa beach
# Processing Record 46 of Set 4 | carnarvon
# Processing Record 47 of Set 4 | airai
# Processing Record 48 of Set 4 | sal rei
# Processing Record 49 of Set 4 | manado
# Processing Record 0 of Set 5 | avera
# Processing Record 1 of Set 5 | florianopolis
# Processing Record 2 of Set 5 | skagastrond
# City not found. Skipping...
# Processing Record 3 of Set 5 | sisimiut
# Processing Record 4 of Set 5 | vanavara
# Processing Record 5 of Set 5 | souillac
# Processing Record 6 of Set 5 | chagda
# City not found. Skipping...
# Processing Record 7 of Set 5 | kodiak
# Processing Record 8 of Set 5 | namatanai
# Processing Record 9 of Set 5 | half moon bay
# Processing Record 10 of Set 5 | batagay-alyta
# Processing Record 11 of Set 5 | ust-kulom
# Processing Record 12 of Set 5 | thompson
# Processing Record 13 of Set 5 | norman wells
# Processing Record 14 of Set 5 | la ronge
# Processing Record 15 of Set 5 | springbok
# Processing Record 16 of Set 5 | victoria
# Processing Record 17 of Set 5 | pirenopolis
# Processing Record 18 of Set 5 | sitka
# Processing Record 19 of Set 5 | kawalu
# Processing Record 20 of Set 5 | vestmanna
# Processing Record 21 of Set 5 | qasigiannguit
# Processing Record 22 of Set 5 | azul
# Processing Record 23 of Set 5 | pagegiai
# Processing Record 24 of Set 5 | kaseda
# Processing Record 25 of Set 5 | dikson
# Processing Record 26 of Set 5 | umm durman
# City not found. Skipping...
# Processing Record 27 of Set 5 | zhitikara
# City not found. Skipping...
# Processing Record 28 of Set 5 | aykhal
# Processing Record 29 of Set 5 | nanortalik
# Processing Record 30 of Set 5 | nyurba
# Processing Record 31 of Set 5 | kaputa
# Processing Record 32 of Set 5 | esperance
# Processing Record 33 of Set 5 | cap malheureux
# Processing Record 34 of Set 5 | gejiu
# Processing Record 35 of Set 5 | severo-kurilsk
# Processing Record 36 of Set 5 | ushtobe
# Processing Record 37 of Set 5 | asau
# Processing Record 38 of Set 5 | uyuni
# Processing Record 39 of Set 5 | tucuman
# Processing Record 40 of Set 5 | vermes
# Processing Record 41 of Set 5 | kenitra
# Processing Record 42 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 43 of Set 5 | pangnirtung
# Processing Record 44 of Set 5 | bambous virieux
# Processing Record 45 of Set 5 | buala
# Processing Record 46 of Set 5 | pisco
# Processing Record 47 of Set 5 | bargal
# City not found. Skipping...
# Processing Record 48 of Set 5 | gulbarga
# Processing Record 49 of Set 5 | chimbote
# Processing Record 0 of Set 6 | enshi
# Processing Record 1 of Set 6 | phan rang
# City not found. Skipping...
# Processing Record 2 of Set 6 | vardo
# Processing Record 3 of Set 6 | verkhovazhye
# Processing Record 4 of Set 6 | college
# Processing Record 5 of Set 6 | cabo san lucas
# Processing Record 6 of Set 6 | hit
# Processing Record 7 of Set 6 | marsaxlokk
# Processing Record 8 of Set 6 | goderich
# Processing Record 9 of Set 6 | ilulissat
# Processing Record 10 of Set 6 | izumo
# Processing Record 11 of Set 6 | tazovskiy
# Processing Record 12 of Set 6 | emba
# Processing Record 13 of Set 6 | faya
# Processing Record 14 of Set 6 | saint george
# Processing Record 15 of Set 6 | longyearbyen
# Processing Record 16 of Set 6 | oum hadjer
# Processing Record 17 of Set 6 | mamou
# Processing Record 18 of Set 6 | maloshuyka
# City not found. Skipping...
# Processing Record 19 of Set 6 | marolambo
# Processing Record 20 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 21 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 22 of Set 6 | mae hong son
# Processing Record 23 of Set 6 | inirida
# Processing Record 24 of Set 6 | kaitangata
# Processing Record 25 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 26 of Set 6 | khani
# Processing Record 27 of Set 6 | poum
# Processing Record 28 of Set 6 | mar del plata
# Processing Record 29 of Set 6 | kharp
# Processing Record 30 of Set 6 | aklavik
# Processing Record 31 of Set 6 | zhanaozen
# Processing Record 32 of Set 6 | kruisfontein
# Processing Record 33 of Set 6 | yulara
# Processing Record 34 of Set 6 | kovdor
# Processing Record 35 of Set 6 | sokoni
# Processing Record 36 of Set 6 | hokitika
# Processing Record 37 of Set 6 | bambari
# Processing Record 38 of Set 6 | nikolskoye
# Processing Record 39 of Set 6 | camacupa
# Processing Record 40 of Set 6 | yialos
# City not found. Skipping...
# Processing Record 41 of Set 6 | fethiye
# Processing Record 42 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 43 of Set 6 | sao miguel do tapuio
# Processing Record 44 of Set 6 | itupiranga
# Processing Record 45 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 46 of Set 6 | bukama
# Processing Record 47 of Set 6 | ballitoville
# Processing Record 48 of Set 6 | slonim
# Processing Record 49 of Set 6 | balikpapan
# Processing Record 0 of Set 7 | berlevag
# Processing Record 1 of Set 7 | vaitape
# Processing Record 2 of Set 7 | flin flon
# Processing Record 3 of Set 7 | matir
# City not found. Skipping...
# Processing Record 4 of Set 7 | marsa matruh
# Processing Record 5 of Set 7 | deputatskiy
# Processing Record 6 of Set 7 | severnyy
# Processing Record 7 of Set 7 | atbasar
# Processing Record 8 of Set 7 | capaci
# Processing Record 9 of Set 7 | najran
# Processing Record 10 of Set 7 | grand gaube
# Processing Record 11 of Set 7 | chifeng
# Processing Record 12 of Set 7 | caranavi
# Processing Record 13 of Set 7 | hirado
# Processing Record 14 of Set 7 | suffolk
# Processing Record 15 of Set 7 | nome
# Processing Record 16 of Set 7 | marzuq
# Processing Record 17 of Set 7 | beringovskiy
# Processing Record 18 of Set 7 | tubuala
# Processing Record 19 of Set 7 | wahran
# Processing Record 10 of Set 10 | san angelo
# Processing Record 11 of Set 10 | dongkan
# Processing Record 12 of Set 10 | hohhot
# Processing Record 13 of Set 10 | komsomolets
# Processing Record 14 of Set 10 | lompoc
# Processing Record 15 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 16 of Set 10 | kotka
# Processing Record 17 of Set 10 | anandnagar
# Processing Record 18 of Set 10 | kurilsk
# Processing Record 19 of Set 10 | kirksville
# Processing Record 20 of Set 10 | rumonge
# Processing Record 21 of Set 10 | gladenbach
# Processing Record 22 of Set 10 | turiacu
# Processing Record 23 of Set 10 | dabou
# Processing Record 24 of Set 10 | mayumba
# Processing Record 25 of Set 10 | udachnyy
# Processing Record 26 of Set 10 | clyde river
# Processing Record 27 of Set 10 | peniche
# Processing Record 28 of Set 10 | pristen
# Processing Record 29 of Set 10 | araci
# Processing Record 30 of Set 10 | lgov
# Processing Record 31 of Set 10 | codrington
# Processing Record 32 of Set 10 | black river
# Processing Record 33 of Set 10 | huazhou
# Processing Record 34 of Set 10 | iqaluit
# Processing Record 35 of Set 10 | luderitz
# Processing Record 36 of Set 10 | zuidhorn
# Processing Record 37 of Set 10 | maceio
# Processing Record 38 of Set 10 | katobu
# Processing Record 39 of Set 10 | soure
# Processing Record 40 of Set 10 | tawkar
# City not found. Skipping...
# Processing Record 41 of Set 10 | glendive
# Processing Record 42 of Set 10 | saint combs
# City not found. Skipping...
# Processing Record 43 of Set 10 | burica
# City not found. Skipping...
# Processing Record 44 of Set 10 | gamba
# Processing Record 45 of Set 10 | tondano
# Processing Record 46 of Set 10 | lasem
# Processing Record 47 of Set 10 | quatre cocos
# Processing Record 48 of Set 10 | fort saint john
# City not found. Skipping...
# Processing Record 49 of Set 10 | mwene-ditu
# Processing Record 0 of Set 11 | madimba
# Processing Record 1 of Set 11 | eyl
# Processing Record 2 of Set 11 | jesenice
# Processing Record 3 of Set 11 | powell river
# Processing Record 4 of Set 11 | mehamn
# Processing Record 5 of Set 11 | sayyan
# Processing Record 6 of Set 11 | karuzi
# Processing Record 7 of Set 11 | talas
# Processing Record 8 of Set 11 | aksarka
# Processing Record 9 of Set 11 | kyrylivka
# Processing Record 10 of Set 11 | makakilo city
# Processing Record 11 of Set 11 | klaksvik
# Processing Record 12 of Set 11 | bandarbeyla
# Processing Record 13 of Set 11 | kabanjahe
# Processing Record 14 of Set 11 | kloulklubed
# Processing Record 15 of Set 11 | bo rai
# Processing Record 16 of Set 11 | srednekolymsk
# Processing Record 17 of Set 11 | mahon
# Processing Record 18 of Set 11 | porto walter
# Processing Record 19 of Set 11 | grindavik
# Processing Record 20 of Set 11 | gbadolite
# Processing Record 21 of Set 11 | camargo
# Processing Record 22 of Set 11 | hvide sande
# Processing Record 23 of Set 11 | vallenar
# Processing Record 24 of Set 11 | yerofey pavlovich
# Processing Record 25 of Set 11 | bonthe
# Processing Record 26 of Set 11 | matay
# Processing Record 27 of Set 11 | portpatrick
# City not found. Skipping...
# Processing Record 28 of Set 11 | husavik
# Processing Record 29 of Set 11 | kita
# Processing Record 30 of Set 11 | freeport
# Processing Record 31 of Set 11 | mopti
# Processing Record 32 of Set 11 | juneau
# Processing Record 33 of Set 11 | angoche
# Processing Record 34 of Set 11 | keflavik
# Processing Record 35 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 36 of Set 11 | zhezkazgan
# Processing Record 37 of Set 11 | beyneu
# Processing Record 38 of Set 11 | mumford
# Processing Record 39 of Set 11 | houma
# Processing Record 40 of Set 11 | egvekinot
# Processing Record 41 of Set 11 | ossora
# Processing Record 42 of Set 11 | rockingham
# Processing Record 43 of Set 11 | fevralsk
# City not found. Skipping...
# Processing Record 44 of Set 11 | sinjar
# Processing Record 45 of Set 11 | oistins
# Processing Record 46 of Set 11 | aktas
# Processing Record 47 of Set 11 | alofi
# Processing Record 48 of Set 11 | lensk
# Processing Record 49 of Set 11 | ende
# Processing Record 0 of Set 12 | kununurra
# Processing Record 1 of Set 12 | talara
# Processing Record 2 of Set 12 | cap-aux-meules
# Processing Record 3 of Set 12 | la libertad
# Processing Record 4 of Set 12 | fukue
# Processing Record 5 of Set 12 | ilan
# Processing Record 6 of Set 12 | zaysan
# Processing Record 7 of Set 12 | danane
# Processing Record 8 of Set 12 | nouakchott
# Processing Record 9 of Set 12 | northam
# Processing Record 10 of Set 12 | kalmunai
# Processing Record 11 of Set 12 | mildura
# Processing Record 12 of Set 12 | malanje
# Processing Record 13 of Set 12 | sereflikochisar
# Processing Record 14 of Set 12 | nhulunbuy
# Processing Record 15 of Set 12 | idenao
# Processing Record 16 of Set 12 | saint anthony
# Processing Record 17 of Set 12 | leh
# Processing Record 18 of Set 12 | broome
# Processing Record 19 of Set 12 | milkovo
# Processing Record 20 of Set 12 | jvari
# Processing Record 21 of Set 12 | ancud
# Processing Record 22 of Set 12 | dedougou
# Processing Record 23 of Set 12 | banavar
# Processing Record 24 of Set 12 | ndele
# Processing Record 25 of Set 12 | barawe
# City not found. Skipping...
# Processing Record 26 of Set 12 | murgud
# Processing Record 27 of Set 12 | dublin
# Processing Record 28 of Set 12 | rudbar
# Processing Record 29 of Set 12 | comodoro rivadavia
# Processing Record 30 of Set 12 | natalinsk
# Processing Record 31 of Set 12 | oriximina
# Processing Record 32 of Set 12 | filingue
# Processing Record 33 of Set 12 | malampaka
# Processing Record 34 of Set 12 | lyuban
# Processing Record 35 of Set 12 | ipixuna
# Processing Record 36 of Set 12 | foz do iguacu
# Processing Record 37 of Set 12 | show low
# Processing Record 38 of Set 12 | ust-nera
# Processing Record 39 of Set 12 | kon tum
# Processing Record 40 of Set 12 | muswellbrook
# Processing Record 41 of Set 12 | conceicao do araguaia
# Processing Record 42 of Set 12 | geraldton
# Processing Record 43 of Set 12 | kieta
# Processing Record 44 of Set 12 | quarai
# Processing Record 45 of Set 12 | yeppoon
# Processing Record 46 of Set 12 | salalah
# Processing Record 47 of Set 12 | ankazoabo
# Processing Record 48 of Set 12 | kavaratti
# Processing Record 49 of Set 12 | havoysund
# Processing Record 0 of Set 13 | brasilia de minas
# Processing Record 1 of Set 13 | charters towers
# Processing Record 2 of Set 13 | chegdomyn
# Processing Record 3 of Set 13 | huaicheng
# Processing Record 4 of Set 13 | muriwai beach
# Processing Record 5 of Set 13 | san patricio
# Processing Record 6 of Set 13 | ceyhan
# Processing Record 7 of Set 13 | achikulak
# Processing Record 8 of Set 13 | la asuncion
# Processing Record 9 of Set 13 | dobrusevo
# Processing Record 10 of Set 13 | billings
# Processing Record 11 of Set 13 | lyubim
# Processing Record 12 of Set 13 | itarema
# Processing Record 13 of Set 13 | pemangkat
# Processing Record 14 of Set 13 | trairi
# Processing Record 15 of Set 13 | wawa
# Processing Record 16 of Set 13 | ulladulla
# Processing Record 17 of Set 13 | giresun
# Processing Record 18 of Set 13 | san quintin
# Processing Record 19 of Set 13 | necochea
# Processing Record 20 of Set 13 | oudtshoorn
# Processing Record 21 of Set 13 | belaya gora
# Processing Record 22 of Set 13 | savelugu
# Processing Record 23 of Set 13 | eydhafushi
# Processing Record 24 of Set 13 | manicore
# Processing Record 25 of Set 13 | nang rong
# Processing Record 26 of Set 13 | lagoa
# Processing Record 27 of Set 13 | denpasar
# -----------------------
# Data Retrieval Complete
# -----------------------

# %% [markdown]
# Convert Raw Data to DataFrame
#
# Export the city data into a .csv.
#
# Display the DataFrame

# %%
#Create  a data frame from all lists

w_dict = {
    "City": cities,
    "Lat": lat1,
    "Lng": lng1,
    "Max Temp": maxT,
    "Humidity": hum,
    "Cloudiness": clouds,
    "Country": country,
    "Wind Speed": wind_spd,
    "Date": date
}

w_data = pd.DataFrame(w_dict)
w_data.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness Country  \
# 0  port elizabeth -33.9180   25.5701     75.20      57.0         0.0      ZA
# 1          vanimo  -2.6741  141.3028     79.59      85.0       100.0      PG
# 2         ushuaia -54.8000  -68.3000     39.20      81.0        40.0      AR
# 3       jamestown  42.0970  -79.2353     18.00      79.0        90.0      US
# 4          hobart -42.8794  147.3294     62.60      88.0        90.0      AU
#
#    Wind Speed          Date
# 0       14.97  1.611929e+09
# 1       10.27  1.611929e+09
# 2       19.57  1.611929e+09
# 3       10.36  1.611929e+09
# 4        9.22  1.611929e+09

# %%
weather_drop = w_data.dropna()
weather_drop.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness Country  \
# 0  port elizabeth -33.9180   25.5701     75.20      57.0         0.0      ZA
# 1          vanimo  -2.6741  141.3028     79.59      85.0       100.0      PG
# 2         ushuaia -54.8000  -68.3000     39.20      81.0        40.0      AR
# 3       jamestown  42.0970  -79.2353     18.00      79.0        90.0      US
# 4          hobart -42.8794  147.3294     62.60      88.0        90.0      AU
#
#    Wind Speed          Date
# 0       14.97  1.611929e+09
# 1       10.27  1.611929e+09
# 2       19.57  1.611929e+09
# 3       10.36  1.611929e+09
# 4        9.22  1.611929e+09

# %%
#Export the city data into a .csv.
weather_drop.to_csv(r'../output_data/city_weather_data.csv', index=False)

# %%
#Read into export csv file
file_path = "../output_data/city_weather_data.csv"
city_weather = pd.read_csv(file_path)
city_weather
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    port elizabeth -33.9180   25.5701     75.20      57.0         0.0
# 1            vanimo  -2.6741  141.3028     79.59      85.0       100.0
# 2           ushuaia -54.8000  -68.3000     39.20      81.0        40.0
# 3         jamestown  42.0970  -79.2353     18.00      79.0        90.0
# 4            hobart -42.8794  147.3294     62.60      88.0        90.0
# ..              ...      ...       ...       ...       ...         ...
# 577      eydhafushi   5.1033   73.0708     80.91      72.0        46.0
# 578        manicore  -5.8092  -61.3003     76.26      93.0        98.0
# 579       nang rong  14.6377  102.7914     81.00      51.0        84.0
# 580           lagoa  39.0500  -27.9833     59.16      71.0       100.0
# 581        denpasar  -8.6500  115.2167     78.80      89.0        75.0
#
#     Country  Wind Speed          Date
# 0        ZA       14.97  1.611929e+09
# 1        PG       10.27  1.611929e+09
# 2        AR       19.57  1.611929e+09
# 3        US       10.36  1.611929e+09
# 4        AU        9.22  1.611929e+09
# ..      ...         ...           ...
# 577      MV       12.75  1.611930e+09
# 578      BR        2.82  1.611930e+09
# 579      TH        6.91  1.611930e+09
# 580      PT       22.39  1.611930e+09
# 581      ID       11.50  1.611929e+09
#
# [582 rows x 9 columns]

# %% [markdown]
# Inspect the data and remove the cities where the humidity > 100%.
#
# Skip this step if there are no cities that have humidity > 100%.

# %%
#Check data to see if cities have humidity >100

# city_weather['Humidity'].max()
# city_weather['Humidity'].describe()
# city_weather['Humidity'] > 100.0

# %% [markdown]
# Plotting the Data
#
# Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
#
# Save the plotted figures as .pngs.

# %% [markdown]
# Latitude vs. Temperature Plot

# %%
x_axis = city_weather['Lat']
y_axis = city_weather['Max Temp']
plt.scatter(x_axis, y_axis, marker="o", facecolors="cyan", edgecolors="black")
plt.title("City Latitude vs. Max Temperature")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.savefig("../Images/LatVSMaxT.png")
plt.grid()
plt.show()
print("Analysis of cities latitude and the maximum temperature of those cities. Latitude is a main factor   affecting temperature, therefore the further a city is from the equator, the lower the temperature.")
# Out:
# Analysis of cities latitude and the maximum temperature of those cities. Latitude is a main factor   affecting temperature, therefore the further a city is from the equator, the lower the temperature.

# %% [markdown]
# Latitude vs. Humidity Plot

# %%
x_axis = city_weather['Lat']
y_axis = city_weather['Humidity']
plt.scatter(x_axis, y_axis, marker="o", facecolors="gold", edgecolors="black")
plt.title("City Latitude vs. Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.savefig("../Images/LatVSHumidity.png")
plt.grid()
plt.show()
print("Analysis of cities latitude and percent humidity of those cities. Humidity appears to have some dependency on latitude, however there are lower humidity values near the equator. This could due to seasonal effects.")
# Out:
# Analysis of cities latitude and percent humidity of those cities. Humidity appears to have some dependency on latitude, however there are lower humidity values near the equator. This could due to seasonal effects.

# %% [markdown]
# Latitude vs. Cloudiness Plot

# %%
x_axis = city_weather['Lat']
y_axis = city_weather['Cloudiness']
plt.scatter(x_axis, y_axis, marker="o", facecolors="palegreen", edgecolors="black")
plt.title("City Latitude vs. Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.savefig("../Images/LatVSCloudiness.png")
plt.grid()
plt.show()
print("Analysis of cities latitude and the percent cloudiness of those cities. Data points are largely      distributed, it doesn't appear that latitude and cloudiness have a direct relationship.")
# Out:
# Analysis of cities latitude and the percent cloudiness of those cities. Data points are largely      distributed, it doesn't appear that latitude and cloudiness have a direct relationship.

# %% [markdown]
# Latitude vs. Wind Speed Plot

# %%
x_axis = city_weather['Lat']
y_axis = city_weather['Wind Speed']
plt.scatter(x_axis, y_axis, marker="o", facecolors="orchid", edgecolors="black")
plt.title("City Latitude vs. Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.savefig("../Images/LatVSWindSpeed.png")
plt.grid()
plt.show()
print("Analysis of cities latitude and wind speed of those cities. Most of the cities are located in a      region with wind speeds below 20mph as lower wind speeds are more concentrated near the equator.")
# Out:
# Analysis of cities latitude and wind speed of those cities. Most of the cities are located in a      region with wind speeds below 20mph as lower wind speeds are more concentrated near the equator.

# %% [markdown]
# Linear Regression

# %% [markdown]
# Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Need to filter data to include only northern hemisphere
#Latitude for northern hemisphere?
#0 degress at the equator and end at 90 degress at the North Poles
#Apply filter to include ALL columns within the city_weather data frame

nhem = city_weather.loc[city_weather['Lat'] >= 0, :]
nhem
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness Country  \
# 3      jamestown  42.0970  -79.2353     18.00      79.0        90.0      US
# 6         apango  17.7333  -99.3333     66.00      60.0       100.0      MX
# 8       hamilton  39.1834  -84.5333     23.00      93.0         1.0      US
# 9           hilo  19.7297 -155.0900     68.00      88.0        90.0      US
# 10        shieli  44.1667   66.7500     29.08      90.0         0.0      KZ
# ..           ...      ...       ...       ...       ...         ...     ...
# 575  belaya gora  68.5333  146.4167    -29.79      84.0       100.0      RU
# 576     savelugu   9.6244   -0.8253    100.53      13.0         0.0      GH
# 577   eydhafushi   5.1033   73.0708     80.91      72.0        46.0      MV
# 579    nang rong  14.6377  102.7914     81.00      51.0        84.0      TH
# 580        lagoa  39.0500  -27.9833     59.16      71.0       100.0      PT
#
#      Wind Speed          Date
# 3         10.36  1.611929e+09
# 6          1.68  1.611929e+09
# 8          1.59  1.611929e+09
# 9         14.97  1.611929e+09
# 10         8.48  1.611929e+09
# ..          ...           ...
# 575        4.25  1.611930e+09
# 576        6.15  1.611930e+09
# 577       12.75  1.611930e+09
# 579        6.91  1.611930e+09
# 580       22.39  1.611930e+09
#
# [395 rows x 9 columns]

# %%
x_axis = nhem['Lat']
y_axis = nhem['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_axis,regress_values,"r-")
plt.scatter(x_axis, y_axis, marker="o", facecolors="lime", edgecolors="black")
plt.title("Northern Hemisphere: Max Temp vs Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")
plt.annotate(line_eq,(2,6),fontsize=15,color="red")
print(f"The r-squared is: {rvalue**2}")
plt.savefig("../Images/NHemMaxTvsLatLinearRegression.png")
plt.show()
# Out:
# The r-squared is: 0.7355459985232428

# %% [markdown]
# Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Southern hemisphere anything >0 degrees lat
shem = city_weather.loc[city_weather['Lat'] < 0, :]
shem
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    port elizabeth -33.9180   25.5701     75.20      57.0         0.0
# 1            vanimo  -2.6741  141.3028     79.59      85.0       100.0
# 2           ushuaia -54.8000  -68.3000     39.20      81.0        40.0
# 4            hobart -42.8794  147.3294     62.60      88.0        90.0
# 5              lebu -37.6167  -73.6500     59.31      97.0        96.0
# ..              ...      ...       ...       ...       ...         ...
# 570       ulladulla -35.3500  150.4667     69.01     100.0        90.0
# 573        necochea -38.5473  -58.7368     81.00      42.0       100.0
# 574      oudtshoorn -33.5907   22.2014     73.40      49.0         0.0
# 578        manicore  -5.8092  -61.3003     76.26      93.0        98.0
# 581        denpasar  -8.6500  115.2167     78.80      89.0        75.0
#
#     Country  Wind Speed          Date
# 0        ZA       14.97  1.611929e+09
# 1        PG       10.27  1.611929e+09
# 2        AR       19.57  1.611929e+09
# 4        AU        9.22  1.611929e+09
# 5        CL        6.13  1.611929e+09
# ..      ...         ...           ...
# 570      AU       10.36  1.611930e+09
# 573      AR       10.80  1.611930e+09
# 574      ZA        8.05  1.611930e+09
# 578      BR        2.82  1.611930e+09
# 581      ID       11.50  1.611929e+09
#
# [187 rows x 9 columns]

# %%
x_axis = shem['Lat']
y_axis = shem['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_axis,regress_values,"r-")
plt.scatter(x_axis, y_axis, marker="o", facecolors="tomato", edgecolors="black")
plt.title("Southern Hemisphere: Max Temp vs Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")
plt.annotate(line_eq, xy=(-30, 50),fontsize=15,color="red")
print(f"The r-squared is: {rvalue**2}")
plt.savefig("../Images/SHemMaxTvsLatLinearRegression.png")
plt.show()
# Out:
# The r-squared is: 0.4396149828192429

# %% [markdown]
# Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_axis = nhem['Lat']
y_axis = nhem['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_axis,regress_values,"r-")
plt.scatter(x_axis, y_axis, marker="o", facecolors="blueviolet", edgecolors="black")
plt.title("Northern Hemisphere: Humidity vs Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.annotate(line_eq,(30,10),fontsize=15,color="red")
print(f"The r-squared is: {rvalue**2}")
plt.savefig("../Images/NHemMHumidityvsLatLinearRegression.png")
plt.show()
# Out:
# The r-squared is: 0.15479309403736766

# %% [markdown]
# Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_axis = shem['Lat']
y_axis = shem['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_axis,regress_values,"r-")
plt.scatter(x_axis, y_axis, marker="o", facecolors="peachpuff", edgecolors="black")
plt.title("Southern Hemisphere: Humidity vs Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.annotate(line_eq,xy=(-25, 20),fontsize=15,color="red")
print(f"The r-squared is: {rvalue**2}")
plt.savefig("../Images/SHemHumvsLatLinearRegression.png")
plt.show()
# Out:
# The r-squared is: 0.025740273750108008

# %% [markdown]
# Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_axis = nhem['Lat']
y_axis = nhem['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_axis,regress_values,"r-")
plt.scatter(x_axis, y_axis, marker="o", facecolors="cornflowerblue", edgecolors="black")
plt.title("Northern Hemisphere: Cloudiness vs Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.annotate(line_eq,(25,10),fontsize=15,color="red")
print(f"The r-squared is: {rvalue**2}")
plt.savefig("../Images/NHemCloudsvsLatLinearRegression.png")
plt.show()
# Out:
# The r-squared is: 0.032400721613694054

# %% [markdown]
# Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_axis = shem['Lat']
y_axis = shem['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_axis,regress_values,"r-")
plt.scatter(x_axis, y_axis, marker="o", facecolors="burlywood", edgecolors="black")
plt.title("Southern Hemisphere: Cloudiness vs Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.annotate(line_eq,xy=(-50, 60),fontsize=15,color="red")
print(f"The r-squared is: {rvalue**2}")
plt.savefig("../Images/SHemCloudsvsLatLinearRegression.png")
plt.show()
# Out:
# The r-squared is: 0.15090569273030338

# %% [markdown]
# Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_axis = nhem['Lat']
y_axis = nhem['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_axis,regress_values,"r-")
plt.scatter(x_axis, y_axis, marker="o", facecolors="aquamarine", edgecolors="black")
plt.title("Northern Hemisphere: Wind Speed vs Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.annotate(line_eq,(5,25),fontsize=15,color="red")
print(f"The r-squared is: {rvalue**2}")
plt.savefig("../Images/NHemWindSpdvsLatLinearRegression.png")
plt.show()
# Out:
# The r-squared is: 0.0016229940343092286

# %% [markdown]
# Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_axis = shem['Lat']
y_axis = shem['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_axis,regress_values,"r-")
plt.scatter(x_axis, y_axis, marker="o", facecolors="lightcoral", edgecolors="black")
plt.title("Southern Hemisphere: Wind Speed vs Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.annotate(line_eq,xy=(-55, 20),fontsize=15,color="red")
print(f"The r-squared is: {rvalue**2}")
plt.savefig("../Images/SHemWindSpdvsLatLinearRegression.png")
plt.show()
# Out:
# The r-squared is: 0.008792401986341953
